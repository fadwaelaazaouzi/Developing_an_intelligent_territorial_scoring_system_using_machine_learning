# %% [markdown]
# # phase  1: data loading and cleaning
#
# **objective:**  load all raw data sheets, clean them individually, merge them into a final dataframe where each row represents one commune

# %% [markdown]
# ## Exploring relevant data sheets

# %%
import pandas as pd

# %%
file_name='Indicateurs démographiques et socioéconomiques du Royaume du Maroc selon les résultats du RGPH 2024.xlsx'
code_geo_file='codegeographique.xlsx'

xls=pd.ExcelFile(file_name)
all_sheet_names= xls.sheet_names
print("available sheets in the excel file")
print(all_sheet_names)
# Out:
# available sheets in the excel file
# ['Population', 'Population_Urbaine', 'Population_Rurale', 'Ménages', 'Ménages_Urbains', 'Ménages_Ruraux', 'Définitions_des_Concepts', 'Signes_Conventionnels', 'Avis_aux_Utilisateurs']

# %%
sheets_to_ignore =['Définitions_des_Concepts','Signes_Conventionnels', 'Avis_aux_Utilisateurs']
data_sheets=[sheet for sheet in all_sheet_names if sheet not in sheets_to_ignore]
print("final list of data sheet to process:", data_sheets)
# Out:
# final list of data sheet to process: ['Population', 'Population_Urbaine', 'Population_Rurale', 'Ménages', 'Ménages_Urbains', 'Ménages_Ruraux']

# %% [markdown]
#  Sheet Inventory :
# *   `Population`:
# *   `Population_Urbaine`:
# *   `Population_Rurale`:
# *   `ménages`:
# *   `ménages_Urbaine`:
# *   `ménages_Rurale`:

# %%
print("---peeking into relevant data sheets:---")

for sheet in data_sheets:
    print(f"---peeking into sheets:{sheet}---")
    df_peek=pd.read_excel(file_name, sheet_name=sheet, header=None, nrows=15)
    print(df_peek)
# Out:
# ---peeking into relevant data sheets---
# ---peeking into sheets:Population---
#                                0                                    1    \
# 0   Milieu de résidence : Ensemble                                  NaN
# 1                              NaN                                  NaN
# 2                Code géographique          Collectivités territoriales
# 3                              NaN      Ensemble du territoire national
# 4                                1  Région de Tanger-Tétouan-Al Hoceima
# 5                             1511         Préfecture de Tanger-Assilah
# 6                          1511010                    Commune de Tanger
# 7                         15110105            Arrondissement de Mghogha
# 8                         15110106             Arrondissement de Souani
# 9                         15110103         Arrondissement de Bni Makada
# 10                        15110107             Arrondissement de Médina
# 11                        15110101                    Commune d'Assilah
# 12                        15110109                  Commune de Gueznaia
# 13                          151105                     Cercle de Tanger
# 14                        15110519               Commune de Hjar Ennhal
#
#                   2                      3         4        5    \
# 0     Sexe : Ensemble                    NaN       NaN      NaN
# 1   Population légale  Population municipale  Sexe (%)      NaN
# 2                 NaN                    NaN  Masculin  Féminin
# 3            36828330               36490591      49.9     50.1
# 4             4030222                4008655      50.8     49.2
# 5             1494413                1487236      50.8     49.2
# 6             1275428                1272718      50.6     49.4
# 7              252656                 252177      50.8     49.2
# 8              111772                 110723      48.4     51.6
# 9              567465                 567326      50.9     49.1
# 10             343535                 342492      50.8     49.2
# 11              36039                  33975      50.2     49.8
# 12              88676                  88673      51.4     48.6
# 13              60807                  58765      52.5     47.5
# 14              27204                  25301      52.2     47.8
#
#                     6        7          8          9    ...  \
# 0                   NaN      NaN        NaN        NaN  ...
# 1   Âge quinquennal (%)      NaN        NaN        NaN  ...
# 2               0-4 ans  5-9 ans  10-14 ans  15-19 ans  ...
# 3                   7.6      9.3        9.6        8.2  ...
# 4                   8.2      9.6        9.4        7.9  ...
# 5                   8.5      9.4        8.8        7.4  ...
# 6                   8.3      9.2        8.6        7.4  ...
# 7                   8.2      9.3          9        7.6  ...
# 8                   5.7      7.1        7.5        6.9  ...
# 9                   9.2      9.9        9.1        7.7  ...
# 10                  7.6      8.6        8.1        6.9  ...
# 11                  7.3      8.6        8.4        7.2  ...
# 12                 10.9     11.5        9.7          7  ...
# 13                 10.3     11.6       10.8        7.9  ...
# 14                 11.1       12       11.2        7.5  ...
#
#                     181                                          182  \
# 0                   NaN                                          NaN
# 1   Taux de chômage (%)  Population active occupée de 15 ans et plus
# 2                   NaN                                          NaN
# 3                  25.9                                      1696785
# 4                    23                                       232294
# 5                  17.8                                       127760
# 6                  17.7                                       114125
# 7                    20                                        21357
# 8                  17.9                                        10972
# 9                  16.6                                        48867
# 10                 17.8                                        32928
# 11                 30.9                                         1858
# 12                 15.5                                         7295
# 13                 17.7                                         2223
# 14                 18.3                                         1191
#
#                                                   183          184  \
# 0                                                 NaN          NaN
# 1   Statut professionnel des actifs occupés de 15 ...          NaN
# 2                                           Employeur  Indépendant
# 3                                                 1.7         11.2
# 4                                                 1.3         11.3
# 5                                                 1.5          7.4
# 6                                                 1.5          6.8
# 7                                                 1.4          6.5
# 8                                                 1.7          9.2
# 9                                                 0.6          5.3
# 10                                                2.9          8.5
# 11                                                2.8         17.7
# 12                                                0.6          5.5
# 13                                                1.7          9.2
# 14                                                3.2          4.5
#
#                           185                       186            187  \
# 0                         NaN                       NaN            NaN
# 1                         NaN                       NaN            NaN
# 2   Salarié du secteur public  Salarié du secteur privé  Aide familial
# 3                        21.7                      58.8            2.8
# 4                        15.4                      62.3              7
# 5                        10.5                      77.1            1.3
# 6                        10.4                      78.4            0.7
# 7                         7.7                      81.2            0.7
# 8                        16.9                      68.9              1
# 9                         8.2                      83.5            0.5
# 10                       13.1                      72.1            0.7
# 11                       20.5                      54.4            1.6
# 12                       13.1                      77.5            0.9
# 13                        7.7                      78.1            2.4
# 14                        6.1                        84            0.7
#
#          188                  189    190
# 0        NaN                  NaN    NaN
# 1        NaN                  NaN    NaN
# 2   Apprenti  Coopérateur/Associé  Autre
# 3        0.4                  0.9    2.4
# 4        0.3                  0.9    1.6
# 5        0.3                  0.7    1.3
# 6        0.3                  0.7    1.3
# 7        0.2                  0.7    1.6
# 8        0.2                  0.5    1.5
# 9        0.4                  0.5    1.1
# 10       0.2                    1    1.4
# 11       0.6                  0.7    1.8
# 12       0.2                  0.7    1.4
# 13       0.3                  0.1    0.5
# 14       0.5                    0      1
#
# [15 rows x 191 columns]
# ---peeking into sheets:Population_Urbaine---
#                              0                                    1    \
# 0   Milieu de résidence : Urbain                                  NaN
# 1                            NaN                                  NaN
# 2              Code géographique          Collectivités territoriales
# 3                            NaN      Ensemble du territoire national
# 4                              1  Région de Tanger-Tétouan-Al Hoceima
# 5                           1511         Préfecture de Tanger-Assilah
# 6                        1511010                    Commune de Tanger
# 7                       15110105            Arrondissement de Mghogha
# 8                       15110106             Arrondissement de Souani
# 9                       15110103         Arrondissement de Bni Makada
# 10                      15110107             Arrondissement de Médina
# 11                      15110101                    Commune d'Assilah
# 12                      15110109                  Commune de Gueznaia
# 13                        151105                     Cercle de Tanger
# 14                      15110519               Commune de Hjar Ennhal
#
#                   2                      3         4        5    \
# 0     Sexe : Ensemble                    NaN       NaN      NaN
# 1   Population légale  Population municipale  Sexe (%)      NaN
# 2                 NaN                    NaN  Masculin  Féminin
# 3            23110108               22921202      49.3     50.7
# 4             2638815                2626188      50.2     49.8
# 5             1402668                1397890      50.7     49.3
# 6             1275428                1272718      50.6     49.4
# 7              252656                 252177      50.8     49.2
# 8              111772                 110723      48.4     51.6
# 9              567465                 567326      50.9     49.1
# 10             343535                 342492      50.8     49.2
# 11              36039                  33975      50.2     49.8
# 12              88676                  88673      51.4     48.6
# 13               1494                   1494      52.7     47.3
# 14                  …                      …         …        …
#
#                     6        7          8          9    ...  \
# 0                   NaN      NaN        NaN        NaN  ...
# 1   Âge quinquennal (%)      NaN        NaN        NaN  ...
# 2               0-4 ans  5-9 ans  10-14 ans  15-19 ans  ...
# 3                   7.1      8.7          9        7.8  ...
# 4                   7.8      9.2          9        7.6  ...
# 5                   8.4      9.3        8.7        7.4  ...
# 6                   8.3      9.2        8.6        7.4  ...
# 7                   8.2      9.3          9        7.6  ...
# 8                   5.7      7.1        7.5        6.9  ...
# 9                   9.2      9.9        9.1        7.7  ...
# 10                  7.6      8.6        8.1        6.9  ...
# 11                  7.3      8.6        8.4        7.2  ...
# 12                 10.9     11.5        9.7          7  ...
# 13                  7.8      7.2        9.6        8.1  ...
# 14                    …        …          …          …  ...
#
#                     181                                          182  \
# 0                   NaN                                          NaN
# 1   Taux de chômage (%)  Population active occupée de 15 ans et plus
# 2                   NaN                                          NaN
# 3                  25.5                                      1465314
# 4                  23.3                                       191272
# 5                  17.8                                       123407
# 6                  17.7                                       114125
# 7                    20                                        21357
# 8                  17.9                                        10972
# 9                  16.6                                        48867
# 10                 17.8                                        32928
# 11                 30.9                                         1858
# 12                 15.5                                         7295
# 13                 10.8                                           83
# 14                    …                                            …
#
#                                                   183          184  \
# 0                                                 NaN          NaN
# 1   Statut professionnel des actifs occupés de 15 ...          NaN
# 2                                           Employeur  Indépendant
# 3                                                 1.9         10.5
# 4                                                 1.5          8.8
# 5                                                 1.5          6.9
# 6                                                 1.5          6.8
# 7                                                 1.4          6.5
# 8                                                 1.7          9.2
# 9                                                 0.6          5.3
# 10                                                2.9          8.5
# 11                                                2.8         17.7
# 12                                                0.6          5.5
# 13                                                  0          3.6
# 14                                                  …            …
#
#                           185                       186            187  \
# 0                         NaN                       NaN            NaN
# 1                         NaN                       NaN            NaN
# 2   Salarié du secteur public  Salarié du secteur privé  Aide familial
# 3                        22.6                      60.4            0.9
# 4                          17                      69.1            0.8
# 5                        10.7                      77.9            0.7
# 6                        10.4                      78.4            0.7
# 7                         7.7                      81.2            0.7
# 8                        16.9                      68.9              1
# 9                         8.2                      83.5            0.5
# 10                       13.1                      72.1            0.7
# 11                       20.5                      54.4            1.6
# 12                       13.1                      77.5            0.9
# 13                       21.7                      72.3            1.2
# 14                          …                         …              …
#
#          188                  189    190
# 0        NaN                  NaN    NaN
# 1        NaN                  NaN    NaN
# 2   Apprenti  Coopérateur/Associé  Autre
# 3        0.4                  0.9    2.4
# 4        0.3                  0.8    1.7
# 5        0.3                  0.7    1.3
# 6        0.3                  0.7    1.3
# 7        0.2                  0.7    1.6
# 8        0.2                  0.5    1.5
# 9        0.4                  0.5    1.1
# 10       0.2                    1    1.4
# 11       0.6                  0.7    1.8
# 12       0.2                  0.7    1.4
# 13         0                  1.2      0
# 14         …                    …      …
#
# [15 rows x 191 columns]
# ---peeking into sheets:Population_Rurale---
#                             0                                    1    \
# 0   Milieu de résidence : Rural                                  NaN
# 1                           NaN                                  NaN
# 2             Code géographique          Collectivités territoriales
# 3                           NaN      Ensemble du territoire national
# 4                             1  Région de Tanger-Tétouan-Al Hoceima
# 5                          1511         Préfecture de Tanger-Assilah
# 6                       1511010                    Commune de Tanger
# 7                      15110105            Arrondissement de Mghogha
# 8                      15110106             Arrondissement de Souani
# 9                      15110103         Arrondissement de Bni Makada
# 10                     15110107             Arrondissement de Médina
# 11                     15110101                    Commune d'Assilah
# 12                     15110109                  Commune de Gueznaia
# 13                       151105                     Cercle de Tanger
# 14                     15110519               Commune de Hjar Ennhal
#
#                   2                      3         4        5    \
# 0     Sexe : Ensemble                    NaN       NaN      NaN
# 1   Population légale  Population municipale  Sexe (%)      NaN
# 2                 NaN                    NaN  Masculin  Féminin
# 3            13718222               13569389      50.8     49.2
# 4             1391407                1382467      51.9     48.1
# 5               91745                  89346      52.5     47.5
# 6                   …                      …         …        …
# 7                   …                      …         …        …
# 8                   …                      …         …        …
# 9                   …                      …         …        …
# 10                  …                      …         …        …
# 11                  …                      …         …        …
# 12                  …                      …         …        …
# 13              59313                  57271      52.5     47.5
# 14              27204                  25301      52.2     47.8
#
#                     6        7          8          9    ...  \
# 0                   NaN      NaN        NaN        NaN  ...
# 1   Âge quinquennal (%)      NaN        NaN        NaN  ...
# 2               0-4 ans  5-9 ans  10-14 ans  15-19 ans  ...
# 3                   8.6     10.3       10.7        8.7  ...
# 4                   8.8     10.2       10.2        8.6  ...
# 5                   9.7       11       10.3        7.8  ...
# 6                     …        …          …          …  ...
# 7                     …        …          …          …  ...
# 8                     …        …          …          …  ...
# 9                     …        …          …          …  ...
# 10                    …        …          …          …  ...
# 11                    …        …          …          …  ...
# 12                    …        …          …          …  ...
# 13                 10.4     11.8       10.8        7.9  ...
# 14                 11.1       12       11.2        7.5  ...
#
#                     181                                          182  \
# 0                   NaN                                          NaN
# 1   Taux de chômage (%)  Population active occupée de 15 ans et plus
# 2                   NaN                                          NaN
# 3                  28.5                                       231470
# 4                  21.4                                        41022
# 5                  17.2                                         4353
# 6                     …                                            …
# 7                     …                                            …
# 8                     …                                            …
# 9                     …                                            …
# 10                    …                                            …
# 11                    …                                            …
# 12                    …                                            …
# 13                 17.9                                         2140
# 14                 18.3                                         1191
#
#                                                   183          184  \
# 0                                                 NaN          NaN
# 1   Statut professionnel des actifs occupés de 15 ...          NaN
# 2                                           Employeur  Indépendant
# 3                                                 0.8         15.8
# 4                                                 0.4         22.7
# 5                                                 1.1         21.8
# 6                                                   …            …
# 7                                                   …            …
# 8                                                   …            …
# 9                                                   …            …
# 10                                                  …            …
# 11                                                  …            …
# 12                                                  …            …
# 13                                                1.8          9.4
# 14                                                3.2          4.5
#
#                           185                       186            187  \
# 0                         NaN                       NaN            NaN
# 1                         NaN                       NaN            NaN
# 2   Salarié du secteur public  Salarié du secteur privé  Aide familial
# 3                        15.9                      48.8           14.8
# 4                         8.2                      30.7           35.6
# 5                         4.8                      53.2           18.2
# 6                           …                         …              …
# 7                           …                         …              …
# 8                           …                         …              …
# 9                           …                         …              …
# 10                          …                         …              …
# 11                          …                         …              …
# 12                          …                         …              …
# 13                        7.2                      78.3            2.4
# 14                        6.1                        84            0.7
#
#          188                  189    190
# 0        NaN                  NaN    NaN
# 1        NaN                  NaN    NaN
# 2   Apprenti  Coopérateur/Associé  Autre
# 3        0.5                    1    2.4
# 4        0.1                  1.4    0.9
# 5        0.2                  0.4    0.4
# 6          …                    …      …
# 7          …                    …      …
# 8          …                    …      …
# 9          …                    …      …
# 10         …                    …      …
# 11         …                    …      …
# 12         …                    …      …
# 13       0.3                    0    0.5
# 14       0.5                    0      1
#
# [15 rows x 191 columns]
# ---peeking into sheets:Ménages---
#                                 0                                    1   \
# 0   Milieu de résidence : Ensemble                                  NaN
# 1                Code géographique          Collectivités territoriales
# 2                              NaN      Ensemble du territoire national
# 3                                1  Région de Tanger-Tétouan-Al Hoceima
# 4                             1511         Préfecture de Tanger-Assilah
# 5                          1511010                    Commune de Tanger
# 6                         15110105            Arrondissement de Mghogha
# 7                         15110106             Arrondissement de Souani
# 8                         15110103         Arrondissement de Bni Makada
# 9                         15110107             Arrondissement de Médina
# 10                        15110101                    Commune d'Assilah
# 11                        15110109                  Commune de Gueznaia
# 12                          151105                     Cercle de Tanger
# 13                        15110519               Commune de Hjar Ennhal
# 14                        15110507                Commune de Dar Chaoui
#
#                        2                   3                           4   \
# 0   Population municipale            Ménages   Taille moyenne des ménages
# 1          Pop_municipale  Ménages population              Taille moyenne
# 2                36490591             9275038                         3.9
# 3                 4008655             1048860                         3.8
# 4                 1487236              418844                         3.6
# 5                 1272718              362062                         3.5
# 6                  252177               70679                         3.6
# 7                  110723               33489                         3.3
# 8                  567326              150816                         3.8
# 9                  342492              107078                         3.2
# 10                  33975                9745                         3.5
# 11                  88673               25039                         3.5
# 12                  58765               14102                         4.2
# 13                  25301                6048                         4.2
# 14                   4469                1078                         4.1
#
#                      5                       6            7   \
# 0   Ménages sédentaires    Type de logement (%)          NaN
# 1                   NaN  Villa / Étage de villa  Appartement
# 2               9263270                     1.9         16.6
# 3               1047295                     0.9         16.1
# 4                418108                     1.4         25.1
# 5                361404                     1.5         25.6
# 6                 70596                       2         14.9
# 7                 33404                     1.2         24.3
# 8                150716                     0.1         16.2
# 9                106688                     3.2         46.5
# 10                 9722                     0.8          9.2
# 11                24991                     0.8         45.3
# 12                14101                     0.9          0.4
# 13                 6048                     1.6          0.2
# 14                 1078                     0.6            0
#
#                   8                             9   ...  \
# 0                NaN                           NaN  ...
# 1   Maison marocaine  Maison sommaire / Bidonville  ...
# 2               58.8                             3  ...
# 3               66.3                             1  ...
# 4               70.2                           0.7  ...
# 5               71.7                           0.4  ...
# 6               82.1                           0.3  ...
# 7               73.7                           0.1  ...
# 8               82.4                           0.5  ...
# 9               49.1                           0.4  ...
# 10              77.1                            12  ...
# 11              52.6                           0.3  ...
# 12              82.2                           0.6  ...
# 13              91.7                           0.2  ...
# 14              34.7                           0.5  ...
#
#                                             28  \
# 0   Mode d’évacuation des déchets ménagers (%)
# 1                  Bac à ordures de la commune
# 2                                         56.5
# 3                                         65.6
# 4                                         86.7
# 5                                         90.1
# 6                                         81.8
# 7                                         84.7
# 8                                         90.1
# 9                                         97.3
# 10                                        68.9
# 11                                        96.3
# 12                                        35.7
# 13                                        46.7
# 14                                        18.3
#
#                                      29              30     31  \
# 0                                   NaN             NaN    NaN
# 1   Camion de la commune / Camion privé  Dans la nature  Autre
# 2                                    15            26.6    1.9
# 3                                   6.5            25.7    2.2
# 4                                     9             3.4    0.9
# 5                                   9.2             0.3    0.4
# 6                                  17.2             0.7    0.4
# 7                                  14.8             0.2    0.3
# 8                                   9.2             0.2    0.5
# 9                                   2.1             0.3    0.3
# 10                                 28.9             1.4    0.7
# 11                                  2.6             0.6    0.4
# 12                                  4.2            48.5   11.5
# 13                                  1.4            37.7   14.2
# 14                                  0.5            80.8    0.5
#
#                                     32           33       34            35  \
# 0   Combustible de cuisson utilisé (%)          NaN      NaN           NaN
# 1                                  Gaz  Électricité  Charbon  Bois énergie
# 2                                 95.2          0.4      0.2             4
# 3                                 97.7          0.4      0.3           1.4
# 4                                 99.3          0.5        0           0.1
# 5                                 99.3          0.6        0             0
# 6                                 99.4          0.4        0             0
# 7                                 99.1          0.7        0             0
# 8                                 99.5          0.4        0             0
# 9                                   99          0.8        0             0
# 10                                99.7          0.2        0             0
# 11                                99.5          0.4        0           0.1
# 12                                  98          0.2      0.6           1.1
# 13                                99.2          0.4      0.2             0
# 14                                89.7          0.1      0.6           9.4
#
#        36                                                 37
# 0     NaN  Distance moyenne des logements à la route goud...
# 1   Autre                                                NaN
# 2     0.2                                                1.5
# 3     0.1                                                2.3
# 4     0.1                                                0.8
# 5     0.1                                                  …
# 6     0.1                                                  …
# 7     0.1                                                  …
# 8     0.1                                                  …
# 9     0.1                                                  …
# 10    0.1                                                  …
# 11    0.1                                                  …
# 12    0.1                                                0.7
# 13    0.1                                                0.6
# 14    0.2                                                0.5
#
# [15 rows x 38 columns]
# ---peeking into sheets:Ménages_Urbains---
#                               0                                    1   \
# 0   Milieu de résidence : Urbain                                  NaN
# 1              Code géographique          Collectivités territoriales
# 2                            NaN      Ensemble du territoire national
# 3                              1  Région de Tanger-Tétouan-Al Hoceima
# 4                           1511         Préfecture de Tanger-Assilah
# 5                        1511010                    Commune de Tanger
# 6                       15110105            Arrondissement de Mghogha
# 7                       15110106             Arrondissement de Souani
# 8                       15110103         Arrondissement de Bni Makada
# 9                       15110107             Arrondissement de Médina
# 10                      15110101                    Commune d'Assilah
# 11                      15110109                  Commune de Gueznaia
# 12                        151105                     Cercle de Tanger
# 13                      15110519               Commune de Hjar Ennhal
# 14                      15110507                Commune de Dar Chaoui
#
#                        2                   3                           4   \
# 0   Population municipale            Ménages   Taille moyenne des ménages
# 1          Pop_municipale  Ménages population              Taille moyenne
# 2                22921202             6173930                         3.7
# 3                 2626188              728766                         3.6
# 4                 1397890              397526                         3.5
# 5                 1272718              362062                         3.5
# 6                  252177               70679                         3.6
# 7                  110723               33489                         3.3
# 8                  567326              150816                         3.8
# 9                  342492              107078                         3.2
# 10                  33975                9745                         3.5
# 11                  88673               25039                         3.5
# 12                   1494                 401                         3.7
# 13                      …                   …                           …
# 14                   1494                 401                         3.7
#
#                      5                       6            7   \
# 0   Ménages sédentaires    Type de logement (%)          NaN
# 1                   NaN  Villa / Étage de villa  Appartement
# 2               6166796                     2.7         24.4
# 3                727486                     1.2           23
# 4                396797                     1.4         26.4
# 5                361404                     1.5         25.6
# 6                 70596                       2         14.9
# 7                 33404                     1.2         24.3
# 8                150716                     0.1         16.2
# 9                106688                     3.2         46.5
# 10                 9722                     0.8          9.2
# 11                24991                     0.8         45.3
# 12                  401                     0.7            0
# 13                    …                       …            …
# 14                  401                     0.7            0
#
#                   8                             9   ...  \
# 0                NaN                           NaN  ...
# 1   Maison marocaine  Maison sommaire / Bidonville  ...
# 2                 68                           3.3  ...
# 3               73.6                           1.1  ...
# 4               70.6                           0.7  ...
# 5               71.7                           0.4  ...
# 6               82.1                           0.3  ...
# 7               73.7                           0.1  ...
# 8               82.4                           0.5  ...
# 9               49.1                           0.4  ...
# 10              77.1                            12  ...
# 11              52.6                           0.3  ...
# 12              67.1                           0.7  ...
# 13                 …                             …  ...
# 14              67.1                           0.7  ...
#
#                                             28  \
# 0   Mode d’évacuation des déchets ménagers (%)
# 1                  Bac à ordures de la commune
# 2                                           79
# 3                                         89.6
# 4                                         89.9
# 5                                         90.1
# 6                                         81.8
# 7                                         84.7
# 8                                         90.1
# 9                                         97.3
# 10                                        68.9
# 11                                        96.3
# 12                                        49.1
# 13                                           …
# 14                                        49.1
#
#                                      29              30     31  \
# 0                                   NaN             NaN    NaN
# 1   Camion de la commune / Camion privé  Dans la nature  Autre
# 2                                  18.4               2    0.7
# 3                                   8.4             1.3    0.6
# 4                                   9.3             0.4    0.4
# 5                                   9.2             0.3    0.4
# 6                                  17.2             0.7    0.4
# 7                                  14.8             0.2    0.3
# 8                                   9.2             0.2    0.5
# 9                                   2.1             0.3    0.3
# 10                                 28.9             1.4    0.7
# 11                                  2.6             0.6    0.4
# 12                                  1.2            48.4    1.2
# 13                                    …               …      …
# 14                                  1.2            48.4    1.2
#
#                                     32           33       34            35  \
# 0   Combustible de cuisson utilisé (%)          NaN      NaN           NaN
# 1                                  Gaz  Électricité  Charbon  Bois énergie
# 2                                 99.2          0.5        0           0.2
# 3                                 99.4          0.5        0             0
# 4                                 99.3          0.5        0             0
# 5                                 99.3          0.6        0             0
# 6                                 99.4          0.4        0             0
# 7                                 99.1          0.7        0             0
# 8                                 99.5          0.4        0             0
# 9                                   99          0.8        0             0
# 10                                99.7          0.2        0             0
# 11                                99.5          0.4        0           0.1
# 12                                 100            0        0             0
# 13                                   …            …        …             …
# 14                                 100            0        0             0
#
#        36                                                 37
# 0     NaN  Distance moyenne des logements à la route goud...
# 1   Autre                                                NaN
# 2     0.1                                                  …
# 3     0.1                                                  …
# 4     0.1                                                  …
# 5     0.1                                                  …
# 6     0.1                                                  …
# 7     0.1                                                  …
# 8     0.1                                                  …
# 9     0.1                                                  …
# 10    0.1                                                  …
# 11    0.1                                                  …
# 12      0                                                  …
# 13      …                                                  …
# 14      0                                                  …
#
# [15 rows x 38 columns]
# ---peeking into sheets:Ménages_Ruraux---
#                              0                                    1   \
# 0   Milieu de résidence : Rural                                  NaN
# 1             Code géographique          Collectivités territoriales
# 2                           NaN      Ensemble du territoire national
# 3                             1  Région de Tanger-Tétouan-Al Hoceima
# 4                          1511         Préfecture de Tanger-Assilah
# 5                       1511010                    Commune de Tanger
# 6                      15110105            Arrondissement de Mghogha
# 7                      15110106             Arrondissement de Souani
# 8                      15110103         Arrondissement de Bni Makada
# 9                      15110107             Arrondissement de Médina
# 10                     15110101                    Commune d'Assilah
# 11                     15110109                  Commune de Gueznaia
# 12                       151105                     Cercle de Tanger
# 13                     15110519               Commune de Hjar Ennhal
# 14                     15110507                Commune de Dar Chaoui
#
#                        2        3                           4   \
# 0   Population municipale  Ménages  Taille moyenne des ménages
# 1      Ménages population      NaN              Taille moyenne
# 2                13569389  3101108                         4.4
# 3                 1382467   320094                         4.3
# 4                   89346    21318                         4.2
# 5                       …        …                           …
# 6                       …        …                           …
# 7                       …        …                           …
# 8                       …        …                           …
# 9                       …        …                           …
# 10                      …        …                           …
# 11                      …        …                           …
# 12                  57271    13701                         4.2
# 13                  25301     6048                         4.2
# 14                   2975      677                         4.4
#
#                      5                       6            7   \
# 0   Ménages sédentaires    Type de logement (%)          NaN
# 1        Pop_municipale  Villa / Étage de villa  Appartement
# 2               3096474                     0.5          1.2
# 3                319809                     0.3          0.3
# 4                 21311                     0.8          0.5
# 5                     …                       …            …
# 6                     …                       …            …
# 7                     …                       …            …
# 8                     …                       …            …
# 9                     …                       …            …
# 10                    …                       …            …
# 11                    …                       …            …
# 12                13700                     0.9          0.4
# 13                 6048                     1.6          0.2
# 14                  677                     0.4            0
#
#                   8                             9   ...  \
# 0                NaN                           NaN  ...
# 1   Maison marocaine  Maison sommaire / Bidonville  ...
# 2               40.5                           2.6  ...
# 3               49.7                           0.7  ...
# 4                 63                           0.5  ...
# 5                  …                             …  ...
# 6                  …                             …  ...
# 7                  …                             …  ...
# 8                  …                             …  ...
# 9                  …                             …  ...
# 10                 …                             …  ...
# 11                 …                             …  ...
# 12              82.7                           0.6  ...
# 13              91.7                           0.2  ...
# 14              15.5                           0.3  ...
#
#                                             28  \
# 0   Mode d’évacuation des déchets ménagers (%)
# 1                  Bac à ordures de la commune
# 2                                         11.8
# 3                                           11
# 4                                         26.3
# 5                                            …
# 6                                            …
# 7                                            …
# 8                                            …
# 9                                            …
# 10                                           …
# 11                                           …
# 12                                        35.4
# 13                                        46.7
# 14                                           0
#
#                                      29              30     31  \
# 0                                   NaN             NaN    NaN
# 1   Camion de la commune / Camion privé  Dans la nature  Autre
# 2                                   8.2            75.5    4.4
# 3                                   2.1            81.1    5.8
# 4                                   3.8              59   10.9
# 5                                     …               …      …
# 6                                     …               …      …
# 7                                     …               …      …
# 8                                     …               …      …
# 9                                     …               …      …
# 10                                    …               …      …
# 11                                    …               …      …
# 12                                  4.3            48.5   11.8
# 13                                  1.4            37.7   14.2
# 14                                    0             100      0
#
#                                     32           33       34            35  \
# 0   Combustible de cuisson utilisé (%)          NaN      NaN           NaN
# 1                                  Gaz  Électricité  Charbon  Bois énergie
# 2                                 87.1          0.3      0.5          11.8
# 3                                   94          0.3        1           4.5
# 4                                 98.1          0.3      0.6           0.9
# 5                                    …            …        …             …
# 6                                    …            …        …             …
# 7                                    …            …        …             …
# 8                                    …            …        …             …
# 9                                    …            …        …             …
# 10                                   …            …        …             …
# 11                                   …            …        …             …
# 12                                97.9          0.2      0.6           1.1
# 13                                99.2          0.4      0.2             0
# 14                                83.6          0.1        1          14.9
#
#        36                                                 37
# 0     NaN  Distance moyenne des logements à la route goud...
# 1   Autre                                                NaN
# 2     0.4                                                1.5
# 3     0.2                                                2.3
# 4     0.1                                                0.8
# 5       …                                                  …
# 6       …                                                  …
# 7       …                                                  …
# 8       …                                                  …
# 9       …                                                  …
# 10      …                                                  …
# 11      …                                                  …
# 12    0.2                                                0.7
# 13    0.1                                                0.6
# 14    0.3                                                0.5
#
# [15 rows x 38 columns]

# %% [markdown]
# This allows for a visual inspection to determine the correct `header` and `skiprows` parameters needed for proper loading.

# %% [markdown]
# **creating the base geographic dataframe**

# %% [markdown]
# **creating Sexe:Ensemble dataframe**

# %%
def excel_col_to_index(col_name):
    """Converts an Excel column name like 'A', 'B', 'AA', 'BQ' into a 0-indexed integer."""
    index = 0
    for char in col_name:
        index = index * 26 + (ord(char.upper()) - ord('A') + 1)
    return index - 1

# %%
start_col_index = excel_col_to_index('C')
end_col_index = excel_col_to_index('BO')

print(f"The 'EMSEMBLE' block starts at column index: {start_col_index}") 
print(f"The 'ENSEMBLE' block ends at column index: {end_col_index}")
# Out:
# The 'EMSEMBLE' block starts at column index: 2
# The 'ENSEMBLE' block ends at column index: 66

# %%
#LOADING SEXE:ENSEMBLE BLOCK
cols_to_use_ensemble= 'C:BO'

rows_to_skip_ensemble=[0]

# %%
import re
def clean_all_column_names(df):
    new_cols=[]
    for col_tuple in df.columns:
        
        flat_col='_'.join([str(level) for level in col_tuple if 'unnamed' not in str(level).lower() and 'nan' not in str(level).lower()])
        
        new_cols.append(flat_col)
    df.columns=new_cols
    clean_cols=df.columns.to_series().astype(str)
    #remove unnamed
    clean_cols = clean_cols.str.replace(r'Unnamed:\s*\d+\s*', '', regex=True)
    
    #remove level followed by any number
    clean_cols=clean_cols.str.replace(r'_level_\d', '', regex=True)
    #remove a numberand an underscore at the start of a string
    clean_cols=clean_cols.str.replace(r'^\d+_', '', regex=True)
    #replace two or more underscores with  one underscore
    clean_cols=clean_cols.str.replace(r'_+', '_', regex=True)

    clean_cols = clean_cols.str.replace(r'^\d_', '', regex=True)
    
    #remove any underscore at the start or beginning
    clean_cols=clean_cols.str.strip('_')
    df.columns=clean_cols
    return df

# %% [markdown]
# **creating Sexe:Masculin dataframe**

# %%
start_col_index = excel_col_to_index('BQ')
end_col_index = excel_col_to_index('DX')

print(f"The 'Masculin' block starts at column index: {start_col_index}") 
print(f"The 'Masculin' block ends at column index: {end_col_index}")
# Out:
# The 'Masculin' block starts at column index: 68
# The 'Masculin' block ends at column index: 127

# %%
start_col_index = excel_col_to_index('DZ')
end_col_index = excel_col_to_index('GI')

print(f"The 'sexe:Feminin' block starts at column index: {start_col_index}") 
print(f"The 'sexe:feminin' block ends at column index: {end_col_index}")
# Out:
# The 'sexe:Feminin' block starts at column index: 129
# The 'sexe:feminin' block ends at column index: 190

# %%
#for base geo dataset
df_code_geographique=pd.read_excel(code_geo_file)
df_Collectivites_territoriales=pd.read_excel(file_name, sheet_name=sheet, skiprows=[0, 2], usecols='B')
df_base_geo = pd.concat([df_code_geographique, df_Collectivites_territoriales], axis=1)
display(df_base_geo.head())
# Out:
#   Code géographique          Collectivités territoriales
# 0                01  Région de Tanger-Tétouan-Al Hoceima
# 1            01.511         Préfecture de Tanger-Assilah
# 2       01.511.01.0                    Commune de Tanger
# 3      01.511.01.05            Arrondissement de Mghogha
# 4      01.511.01.06             Arrondissement de Souani

# %% [markdown]
# **"Population Processor" Function**:
#
# *goal*:return a single, fully cleaned and joined DataFrame for one population( ensemble , urbaine or rurale) sheet.
#
# *This function will take two arguments:* the file_name and the sheet_name.

# %% [markdown]
# TOTALE STANDS FOR ALL OVER MOROCCO
# ENSEMBLE STANDS FOR ALL GENDERS

# %%
def process_population_sheet(file, sheet):
    print(f"processing population sheet:{sheet}")
    suffix=""
    if "Population_Urbaine" in sheet:
        suffix="_URBAIN"
    elif "Population_Rurale" in sheet:
        suffix="_RURALE"
    elif "Population" in sheet:
        suffix="_TOTAL"
    df_full_sheet=pd.read_excel(file,sheet_name=sheet,
                                  header=[0, 1],
                                  skiprows=[0,3],
                                
                                  )
   
    
   
    
    #for the Ensemble block:
    df_total_raw=df_full_sheet.iloc[:,2:67]

    df_total_clean=clean_all_column_names(df_total_raw)
    full_suffix_total='_ENSEMBLE'+ suffix
    df_total_clean=df_total_clean.add_suffix(full_suffix_total)

    #for the masculin block 
    df_masculin_raw=df_full_sheet.iloc[:,68:128]

    df_masculin_clean=clean_all_column_names(df_masculin_raw)
    full_suffix_total='_HOMMES'+ suffix
    df_masculin_clean=df_masculin_clean.add_suffix(full_suffix_total)
    
    df_masculin_clean.columns=df_masculin_clean.columns.str.replace('1_HOMMES', '_HOMMES', regex=False)
    # For the Féminin block:
    df_feminin_raw=df_full_sheet.iloc[:,129:191]
    full_suffix_feminin = '_FEMMES' + suffix

    df_feminin_clean=clean_all_column_names(df_feminin_raw)
    
    df_feminin_clean=df_feminin_clean.add_suffix(full_suffix_feminin)
    df_feminin_clean.columns=df_feminin_clean.columns.str.replace('2_FEMMES', '_FEMMES', regex=False)

    #join the blocks
    df_processed = pd.concat([ df_total_clean, df_masculin_clean, df_feminin_clean], axis=1)
    print(f"---finished processing{sheet}. Shape: {df_processed.shape}---")
    
    return df_processed

df_pop_total = process_population_sheet(file_name, 'Population')
df_pop_urbain = process_population_sheet(file_name, 'Population_Urbaine')
df_pop_rurale = process_population_sheet(file_name, 'Population_Rurale')
# Out:
# processing population sheet:Population
# ---finished processingPopulation. Shape: (2016, 187)---
# processing population sheet:Population_Urbaine
# ---finished processingPopulation_Urbaine. Shape: (2016, 187)---
# processing population sheet:Population_Rurale
# ---finished processingPopulation_Rurale. Shape: (2016, 187)---

# %% [markdown]
# in the master dataset the headers will be like this: titleofthecolumn_GENDER(H/F)_LOCATION(URBAIN/RURAL)

# %%
print(df_pop_total.head())
# Out:
#    Population légale_ENSEMBLE_TOTAL  Population municipale_ENSEMBLE_TOTAL  \
# 0                           4030222                               4008655
# 1                           1494413                               1487236
# 2                           1275428                               1272718
# 3                            252656                                252177
# 4                            111772                                110723
#
#   Sexe (%)_Masculin_ENSEMBLE_TOTAL Sexe (%)_Féminin_ENSEMBLE_TOTAL  \
# 0                             50.8                            49.2
# 1                             50.8                            49.2
# 2                             50.6                            49.4
# 3                             50.8                            49.2
# 4                             48.4                            51.6
#
#   Âge quinquennal (%)_0-4 ans_ENSEMBLE_TOTAL  \
# 0                                        8.2
# 1                                        8.5
# 2                                        8.3
# 3                                        8.2
# 4                                        5.7
#
#   Âge quinquennal (%)_5-9 ans_ENSEMBLE_TOTAL  \
# 0                                        9.6
# 1                                        9.4
# 2                                        9.2
# 3                                        9.3
# 4                                        7.1
#
#   Âge quinquennal (%)_10-14 ans_ENSEMBLE_TOTAL  \
# 0                                          9.4
# 1                                          8.8
# 2                                          8.6
# 3                                            9
# 4                                          7.5
#
#   Âge quinquennal (%)_15-19 ans_ENSEMBLE_TOTAL  \
# 0                                          7.9
# 1                                          7.4
# 2                                          7.4
# 3                                          7.6
# 4                                          6.9
#
#   Âge quinquennal (%)_20-24 ans_ENSEMBLE_TOTAL  \
# 0                                          7.7
# 1                                          8.3
# 2                                          8.5
# 3                                          8.5
# 4                                          7.4
#
#   Âge quinquennal (%)_25-29 ans_ENSEMBLE_TOTAL  ...  \
# 0                                          7.7  ...
# 1                                          8.9  ...
# 2                                          9.1  ...
# 3                                          9.1  ...
# 4                                          7.6  ...
#
#   Taux de chômage (%)_FEMMES_TOTAL  \
# 0                               23
# 1                             17.8
# 2                             17.7
# 3                               20
# 4                             17.9
#
#   Population active occupée de 15 ans et plus_FEMMES_TOTAL  \
# 0                                             232294
# 1                                             127760
# 2                                             114125
# 3                                              21357
# 4                                              10972
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Employeur._FEMMES_TOTAL  \
# 0                                                1.3
# 1                                                1.5
# 2                                                1.5
# 3                                                1.4
# 4                                                1.7
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Indépendant._FEMMES_TOTAL  \
# 0                                               11.3
# 1                                                7.4
# 2                                                6.8
# 3                                                6.5
# 4                                                9.2
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Salarié du secteur public._FEMMES_TOTAL  \
# 0                                               15.4
# 1                                               10.5
# 2                                               10.4
# 3                                                7.7
# 4                                               16.9
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Salarié du secteur privé._FEMMES_TOTAL  \
# 0                                               62.3
# 1                                               77.1
# 2                                               78.4
# 3                                               81.2
# 4                                               68.9
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Aide familial._FEMMES_TOTAL  \
# 0                                                  7
# 1                                                1.3
# 2                                                0.7
# 3                                                0.7
# 4                                                  1
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Apprenti._FEMMES_TOTAL  \
# 0                                                0.3
# 1                                                0.3
# 2                                                0.3
# 3                                                0.2
# 4                                                0.2
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Coopérateur/Associé._FEMMES_TOTAL  \
# 0                                                0.9
# 1                                                0.7
# 2                                                0.7
# 3                                                0.7
# 4                                                0.5
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Autre._FEMMES_TOTAL
# 0                                                1.6
# 1                                                1.3
# 2                                                1.3
# 3                                                1.6
# 4                                                1.5
#
# [5 rows x 187 columns]

# %%
df_pop_total.to_csv('population.csv', index=False)

# %%
display(df_pop_urbain.head())
# Out:
#   Population légale_ENSEMBLE_URBAIN Population municipale_ENSEMBLE_URBAIN  \
# 0                           2638815                               2626188
# 1                           1402668                               1397890
# 2                           1275428                               1272718
# 3                            252656                                252177
# 4                            111772                                110723
#
#   Sexe (%)_Masculin_ENSEMBLE_URBAIN Sexe (%)_Féminin_ENSEMBLE_URBAIN  \
# 0                              50.2                             49.8
# 1                              50.7                             49.3
# 2                              50.6                             49.4
# 3                              50.8                             49.2
# 4                              48.4                             51.6
#
#   Âge quinquennal (%)_0-4 ans_ENSEMBLE_URBAIN  \
# 0                                         7.8
# 1                                         8.4
# 2                                         8.3
# 3                                         8.2
# 4                                         5.7
#
#   Âge quinquennal (%)_5-9 ans_ENSEMBLE_URBAIN  \
# 0                                         9.2
# 1                                         9.3
# 2                                         9.2
# 3                                         9.3
# 4                                         7.1
#
#   Âge quinquennal (%)_10-14 ans_ENSEMBLE_URBAIN  \
# 0                                             9
# 1                                           8.7
# 2                                           8.6
# 3                                             9
# 4                                           7.5
#
#   Âge quinquennal (%)_15-19 ans_ENSEMBLE_URBAIN  \
# 0                                           7.6
# 1                                           7.4
# 2                                           7.4
# 3                                           7.6
# 4                                           6.9
#
#   Âge quinquennal (%)_20-24 ans_ENSEMBLE_URBAIN  \
# 0                                           7.9
# 1                                           8.4
# 2                                           8.5
# 3                                           8.5
# 4                                           7.4
#
#   Âge quinquennal (%)_25-29 ans_ENSEMBLE_URBAIN  ...  \
# 0                                           8.1  ...
# 1                                           9.1  ...
# 2                                           9.1  ...
# 3                                           9.1  ...
# 4                                           7.6  ...
#
#   Taux de chômage (%)_FEMMES_URBAIN  \
# 0                              23.3
# 1                              17.8
# 2                              17.7
# 3                                20
# 4                              17.9
#
#   Population active occupée de 15 ans et plus_FEMMES_URBAIN  \
# 0                                             191272
# 1                                             123407
# 2                                             114125
# 3                                              21357
# 4                                              10972
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Employeur._FEMMES_URBAIN  \
# 0                                                1.5
# 1                                                1.5
# 2                                                1.5
# 3                                                1.4
# 4                                                1.7
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Indépendant._FEMMES_URBAIN  \
# 0                                                8.8
# 1                                                6.9
# 2                                                6.8
# 3                                                6.5
# 4                                                9.2
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Salarié du secteur public._FEMMES_URBAIN  \
# 0                                                 17
# 1                                               10.7
# 2                                               10.4
# 3                                                7.7
# 4                                               16.9
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Salarié du secteur privé._FEMMES_URBAIN  \
# 0                                               69.1
# 1                                               77.9
# 2                                               78.4
# 3                                               81.2
# 4                                               68.9
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Aide familial._FEMMES_URBAIN  \
# 0                                                0.8
# 1                                                0.7
# 2                                                0.7
# 3                                                0.7
# 4                                                  1
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Apprenti._FEMMES_URBAIN  \
# 0                                                0.3
# 1                                                0.3
# 2                                                0.3
# 3                                                0.2
# 4                                                0.2
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Coopérateur/Associé._FEMMES_URBAIN  \
# 0                                                0.8
# 1                                                0.7
# 2                                                0.7
# 3                                                0.7
# 4                                                0.5
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Autre._FEMMES_URBAIN
# 0                                                1.7
# 1                                                1.3
# 2                                                1.3
# 3                                                1.6
# 4                                                1.5
#
# [5 rows x 187 columns]

# %%
display(df_pop_rurale.head())
# Out:
#   Population légale_ENSEMBLE_RURALE Population municipale_ENSEMBLE_RURALE  \
# 0                           1391407                               1382467
# 1                             91745                                 89346
# 2                                 …                                     …
# 3                                 …                                     …
# 4                                 …                                     …
#
#   Sexe (%)_Masculin_ENSEMBLE_RURALE Sexe (%)_Féminin_ENSEMBLE_RURALE  \
# 0                              51.9                             48.1
# 1                              52.5                             47.5
# 2                                 …                                …
# 3                                 …                                …
# 4                                 …                                …
#
#   Âge quinquennal (%)_0-4 ans_ENSEMBLE_RURALE  \
# 0                                         8.8
# 1                                         9.7
# 2                                           …
# 3                                           …
# 4                                           …
#
#   Âge quinquennal (%)_5-9 ans_ENSEMBLE_RURALE  \
# 0                                        10.2
# 1                                          11
# 2                                           …
# 3                                           …
# 4                                           …
#
#   Âge quinquennal (%)_10-14 ans_ENSEMBLE_RURALE  \
# 0                                          10.2
# 1                                          10.3
# 2                                             …
# 3                                             …
# 4                                             …
#
#   Âge quinquennal (%)_15-19 ans_ENSEMBLE_RURALE  \
# 0                                           8.6
# 1                                           7.8
# 2                                             …
# 3                                             …
# 4                                             …
#
#   Âge quinquennal (%)_20-24 ans_ENSEMBLE_RURALE  \
# 0                                           7.3
# 1                                           7.1
# 2                                             …
# 3                                             …
# 4                                             …
#
#   Âge quinquennal (%)_25-29 ans_ENSEMBLE_RURALE  ...  \
# 0                                             7  ...
# 1                                           6.7  ...
# 2                                             …  ...
# 3                                             …  ...
# 4                                             …  ...
#
#   Taux de chômage (%)_FEMMES_RURALE  \
# 0                              21.4
# 1                              17.2
# 2                                 …
# 3                                 …
# 4                                 …
#
#   Population active occupée de 15 ans et plus_FEMMES_RURALE  \
# 0                                              41022
# 1                                               4353
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Employeur._FEMMES_RURALE  \
# 0                                                0.4
# 1                                                1.1
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Indépendant._FEMMES_RURALE  \
# 0                                               22.7
# 1                                               21.8
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Salarié du secteur public._FEMMES_RURALE  \
# 0                                                8.2
# 1                                                4.8
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Salarié du secteur privé._FEMMES_RURALE  \
# 0                                               30.7
# 1                                               53.2
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Aide familial._FEMMES_RURALE  \
# 0                                               35.6
# 1                                               18.2
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Apprenti._FEMMES_RURALE  \
# 0                                                0.1
# 1                                                0.2
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Coopérateur/Associé._FEMMES_RURALE  \
# 0                                                1.4
# 1                                                0.4
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Statut professionnel des actifs occupés de 15 ans et plus (%)_Autre._FEMMES_RURALE
# 0                                                0.9
# 1                                                0.4
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
# [5 rows x 187 columns]

# %%
start_col_index = excel_col_to_index('D')
end_col_index = excel_col_to_index('AL')

print(f"The 'MENAGES'  starts at column index: {start_col_index}") 
print(f"The 'MENAGES' block ends at column index: {end_col_index}")
# Out:
# The 'MENAGES'  starts at column index: 3
# The 'MENAGES' block ends at column index: 37

# %% [markdown]
# **menage processor function**

# %%
def process_menages_sheet(file, sheet):
    print(f"processing menage sheet:{sheet}")
    suffix=""
    if "Ménages_Urbains" in sheet:
        suffix="_URBAIN"
    elif "Ménages_Ruraux" in sheet:
        suffix="_RURALE"
    elif "Ménages" in sheet:
        suffix="_TOTAL"
    df_full_sheet=pd.read_excel(file,sheet_name=sheet, skiprows=[2],header=[0,1]
                                  )
   
    
   
    
    
    df_total_raw=df_full_sheet.iloc[:,3:38]
    df_total_clean=clean_all_column_names(df_total_raw)
    df_total_clean=df_total_clean.rename(columns={'Ménages _Ménages population': 'Ménages', 'Taille moyenne des ménages_Taille moyenne': 'Taille moyenne des ménages' })

    
    
    df_processed=df_total_clean.add_suffix(suffix)
    
    

    print(f"---finished processing{sheet}. Shape: {df_processed.shape}---")
    
    return df_processed

df_menages_totaux = process_menages_sheet(file_name, 'Ménages')
df_menages_urbains = process_menages_sheet(file_name, 'Ménages_Urbains')
df_menages_ruraux = process_menages_sheet(file_name, 'Ménages_Ruraux')
# Out:
# processing menage sheet:Ménages
# ---finished processingMénages. Shape: (2016, 35)---
# processing menage sheet:Ménages_Urbains
# ---finished processingMénages_Urbains. Shape: (2016, 35)---
# processing menage sheet:Ménages_Ruraux
# ---finished processingMénages_Ruraux. Shape: (2016, 35)---

# %%
df_menages_totaux.to_csv('menages.csv', index=False)

# %%
display(df_menages_totaux.head())
# Out:
#    Ménages_TOTALE  Taille moyenne des ménages_TOTALE  \
# 0         1048860                                3.8
# 1          418844                                3.6
# 2          362062                                3.5
# 3           70679                                3.6
# 4           33489                                3.3
#
#    Ménages sédentaires_TOTALE  \
# 0                     1047295
# 1                      418108
# 2                      361404
# 3                       70596
# 4                       33404
#
#   Type de logement (%)_Villa / Étage de villa_TOTALE  \
# 0                                                0.9
# 1                                                1.4
# 2                                                1.5
# 3                                                  2
# 4                                                1.2
#
#   Type de logement (%)_Appartement_TOTALE  \
# 0                                    16.1
# 1                                    25.1
# 2                                    25.6
# 3                                    14.9
# 4                                    24.3
#
#   Type de logement (%)_Maison marocaine_TOTALE  \
# 0                                         66.3
# 1                                         70.2
# 2                                         71.7
# 3                                         82.1
# 4                                         73.7
#
#   Type de logement (%)_Maison sommaire / Bidonville_TOTALE  \
# 0                                                  1
# 1                                                0.7
# 2                                                0.4
# 3                                                0.3
# 4                                                0.1
#
#   Type de logement (%)_Logement rural_TOTALE  \
# 0                                         15
# 1                                        1.9
# 2                                        0.1
# 3                                        0.1
# 4                                        0.1
#
#   Type de logement (%)_Autre_TOTALE  \
# 0                               0.7
# 1                               0.7
# 2                               0.7
# 3                               0.6
# 4                               0.7
#
#   Nombre moyen de personnes par pièce d'habitation_TOTALE  ...  \
# 0                                                1.5       ...
# 1                                                1.4       ...
# 2                                                1.4       ...
# 3                                                1.4       ...
# 4                                                1.2       ...
#
#   Mode d’évacuation des déchets ménagers (%)_Bac à ordures de la commune_TOTALE  \
# 0                                               65.6
# 1                                               86.7
# 2                                               90.1
# 3                                               81.8
# 4                                               84.7
#
#   Mode d’évacuation des déchets ménagers (%)_Camion de la commune / Camion privé_TOTALE  \
# 0                                                6.5
# 1                                                  9
# 2                                                9.2
# 3                                               17.2
# 4                                               14.8
#
#   Mode d’évacuation des déchets ménagers (%)_Dans la nature_TOTALE  \
# 0                                               25.7
# 1                                                3.4
# 2                                                0.3
# 3                                                0.7
# 4                                                0.2
#
#   Mode d’évacuation des déchets ménagers (%)_Autre_TOTALE  \
# 0                                                2.2
# 1                                                0.9
# 2                                                0.4
# 3                                                0.4
# 4                                                0.3
#
#   Combustible de cuisson utilisé (%)_Gaz_TOTALE  \
# 0                                          97.7
# 1                                          99.3
# 2                                          99.3
# 3                                          99.4
# 4                                          99.1
#
#   Combustible de cuisson utilisé (%)_Électricité_TOTALE  \
# 0                                                0.4
# 1                                                0.5
# 2                                                0.6
# 3                                                0.4
# 4                                                0.7
#
#   Combustible de cuisson utilisé (%)_Charbon_TOTALE  \
# 0                                               0.3
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
#
#   Combustible de cuisson utilisé (%)_Bois énergie_TOTALE  \
# 0                                                1.4
# 1                                                0.1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Combustible de cuisson utilisé (%)_Autre_TOTALE  \
# 0                                             0.1
# 1                                             0.1
# 2                                             0.1
# 3                                             0.1
# 4                                             0.1
#
#   Distance moyenne des logements à la route goudronnée (Km)_TOTALE
# 0                                                2.3
# 1                                                0.8
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
# [5 rows x 35 columns]

# %%
display(df_menages_urbains.head())
# Out:
#   Ménages_URBAIN Taille moyenne des ménages_URBAIN Ménages sédentaires_URBAIN  \
# 0         728766                               3.6                     727486
# 1         397526                               3.5                     396797
# 2         362062                               3.5                     361404
# 3          70679                               3.6                      70596
# 4          33489                               3.3                      33404
#
#   Type de logement (%)_Villa / Étage de villa_URBAIN  \
# 0                                                1.2
# 1                                                1.4
# 2                                                1.5
# 3                                                  2
# 4                                                1.2
#
#   Type de logement (%)_Appartement_URBAIN  \
# 0                                      23
# 1                                    26.4
# 2                                    25.6
# 3                                    14.9
# 4                                    24.3
#
#   Type de logement (%)_Maison marocaine_URBAIN  \
# 0                                         73.6
# 1                                         70.6
# 2                                         71.7
# 3                                         82.1
# 4                                         73.7
#
#   Type de logement (%)_Maison sommaire / Bidonville_URBAIN  \
# 0                                                1.1
# 1                                                0.7
# 2                                                0.4
# 3                                                0.3
# 4                                                0.1
#
#   Type de logement (%)_Logement rural_URBAIN  \
# 0                                        0.4
# 1                                        0.1
# 2                                        0.1
# 3                                        0.1
# 4                                        0.1
#
#   Type de logement (%)_Autre_URBAIN  \
# 0                               0.6
# 1                               0.7
# 2                               0.7
# 3                               0.6
# 4                               0.7
#
#   Nombre moyen de personnes par pièce d'habitation_URBAIN  ...  \
# 0                                                1.4       ...
# 1                                                1.4       ...
# 2                                                1.4       ...
# 3                                                1.4       ...
# 4                                                1.2       ...
#
#   Mode d’évacuation des déchets ménagers (%)_Bac à ordures de la commune_URBAIN  \
# 0                                               89.6
# 1                                               89.9
# 2                                               90.1
# 3                                               81.8
# 4                                               84.7
#
#   Mode d’évacuation des déchets ménagers (%)_Camion de la commune / Camion privé_URBAIN  \
# 0                                                8.4
# 1                                                9.3
# 2                                                9.2
# 3                                               17.2
# 4                                               14.8
#
#   Mode d’évacuation des déchets ménagers (%)_Dans la nature_URBAIN  \
# 0                                                1.3
# 1                                                0.4
# 2                                                0.3
# 3                                                0.7
# 4                                                0.2
#
#   Mode d’évacuation des déchets ménagers (%)_Autre_URBAIN  \
# 0                                                0.6
# 1                                                0.4
# 2                                                0.4
# 3                                                0.4
# 4                                                0.3
#
#   Combustible de cuisson utilisé (%)_Gaz_URBAIN  \
# 0                                          99.4
# 1                                          99.3
# 2                                          99.3
# 3                                          99.4
# 4                                          99.1
#
#   Combustible de cuisson utilisé (%)_Électricité_URBAIN  \
# 0                                                0.5
# 1                                                0.5
# 2                                                0.6
# 3                                                0.4
# 4                                                0.7
#
#   Combustible de cuisson utilisé (%)_Charbon_URBAIN  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
#
#   Combustible de cuisson utilisé (%)_Bois énergie_URBAIN  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Combustible de cuisson utilisé (%)_Autre_URBAIN  \
# 0                                             0.1
# 1                                             0.1
# 2                                             0.1
# 3                                             0.1
# 4                                             0.1
#
#   Distance moyenne des logements à la route goudronnée (Km)_URBAIN
# 0                                                  …
# 1                                                  …
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
# [5 rows x 35 columns]

# %%
display(df_menages_ruraux.head())
# Out:
#   Ménages_RURALE Taille moyenne des ménages_RURALE  \
# 0         320094                               4.3
# 1          21318                               4.2
# 2              …                                 …
# 3              …                                 …
# 4              …                                 …
#
#   Ménages sédentaires_Pop_municipale_RURALE  \
# 0                                    319809
# 1                                     21311
# 2                                         …
# 3                                         …
# 4                                         …
#
#   Type de logement (%)_Villa / Étage de villa_RURALE  \
# 0                                                0.3
# 1                                                0.8
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Type de logement (%)_Appartement_RURALE  \
# 0                                     0.3
# 1                                     0.5
# 2                                       …
# 3                                       …
# 4                                       …
#
#   Type de logement (%)_Maison marocaine_RURALE  \
# 0                                         49.7
# 1                                           63
# 2                                            …
# 3                                            …
# 4                                            …
#
#   Type de logement (%)_Maison sommaire / Bidonville_RURALE  \
# 0                                                0.7
# 1                                                0.5
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Type de logement (%)_Logement rural_RURALE  \
# 0                                       48.1
# 1                                       34.2
# 2                                          …
# 3                                          …
# 4                                          …
#
#   Type de logement (%)_Autre_RURALE  \
# 0                               0.8
# 1                                 1
# 2                                 …
# 3                                 …
# 4                                 …
#
#   Nombre moyen de personnes par pièce d'habitation_RURALE  ...  \
# 0                                                1.7       ...
# 1                                                1.8       ...
# 2                                                  …       ...
# 3                                                  …       ...
# 4                                                  …       ...
#
#   Mode d’évacuation des déchets ménagers (%)_Bac à ordures de la commune_RURALE  \
# 0                                                 11
# 1                                               26.3
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Mode d’évacuation des déchets ménagers (%)_Camion de la commune / Camion privé_RURALE  \
# 0                                                2.1
# 1                                                3.8
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Mode d’évacuation des déchets ménagers (%)_Dans la nature_RURALE  \
# 0                                               81.1
# 1                                                 59
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Mode d’évacuation des déchets ménagers (%)_Autre_RURALE  \
# 0                                                5.8
# 1                                               10.9
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Combustible de cuisson utilisé (%)_Gaz_RURALE  \
# 0                                            94
# 1                                          98.1
# 2                                             …
# 3                                             …
# 4                                             …
#
#   Combustible de cuisson utilisé (%)_Électricité_RURALE  \
# 0                                                0.3
# 1                                                0.3
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Combustible de cuisson utilisé (%)_Charbon_RURALE  \
# 0                                                 1
# 1                                               0.6
# 2                                                 …
# 3                                                 …
# 4                                                 …
#
#   Combustible de cuisson utilisé (%)_Bois énergie_RURALE  \
# 0                                                4.5
# 1                                                0.9
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Combustible de cuisson utilisé (%)_Autre_RURALE  \
# 0                                             0.2
# 1                                             0.1
# 2                                               …
# 3                                               …
# 4                                               …
#
#   Distance moyenne des logements à la route goudronnée (Km)_RURALE
# 0                                                2.3
# 1                                                0.8
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Fusion step

# %%
df_master=pd.concat([df_base_geo, df_pop_total, df_menages_totaux, df_pop_urbain, df_menages_urbains,
                   df_pop_rurale, df_menages_ruraux], axis=1)

# %%
df_master.to_csv('master_df.csv', index=False)

# %%
print(df_master.head())
# Out:
#   Code géographique          Collectivités territoriales  \
# 0                01  Région de Tanger-Tétouan-Al Hoceima
# 1            01.511         Préfecture de Tanger-Assilah
# 2       01.511.01.0                    Commune de Tanger
# 3      01.511.01.05            Arrondissement de Mghogha
# 4      01.511.01.06             Arrondissement de Souani
#
#    Population légale_ENSEMBLE_TOTAL  Population municipale_ENSEMBLE_TOTAL  \
# 0                           4030222                               4008655
# 1                           1494413                               1487236
# 2                           1275428                               1272718
# 3                            252656                                252177
# 4                            111772                                110723
#
#   Sexe (%)_Masculin_ENSEMBLE_TOTAL Sexe (%)_Féminin_ENSEMBLE_TOTAL  \
# 0                             50.8                            49.2
# 1                             50.8                            49.2
# 2                             50.6                            49.4
# 3                             50.8                            49.2
# 4                             48.4                            51.6
#
#   Âge quinquennal (%)_0-4 ans_ENSEMBLE_TOTAL  \
# 0                                        8.2
# 1                                        8.5
# 2                                        8.3
# 3                                        8.2
# 4                                        5.7
#
#   Âge quinquennal (%)_5-9 ans_ENSEMBLE_TOTAL  \
# 0                                        9.6
# 1                                        9.4
# 2                                        9.2
# 3                                        9.3
# 4                                        7.1
#
#   Âge quinquennal (%)_10-14 ans_ENSEMBLE_TOTAL  \
# 0                                          9.4
# 1                                          8.8
# 2                                          8.6
# 3                                            9
# 4                                          7.5
#
#   Âge quinquennal (%)_15-19 ans_ENSEMBLE_TOTAL  ...  \
# 0                                          7.9  ...
# 1                                          7.4  ...
# 2                                          7.4  ...
# 3                                          7.6  ...
# 4                                          6.9  ...
#
#   Mode d’évacuation des déchets ménagers (%)_Bac à ordures de la commune_RURALE  \
# 0                                                 11
# 1                                               26.3
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Mode d’évacuation des déchets ménagers (%)_Camion de la commune / Camion privé_RURALE  \
# 0                                                2.1
# 1                                                3.8
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Mode d’évacuation des déchets ménagers (%)_Dans la nature_RURALE  \
# 0                                               81.1
# 1                                                 59
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Mode d’évacuation des déchets ménagers (%)_Autre_RURALE  \
# 0                                                5.8
# 1                                               10.9
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Combustible de cuisson utilisé (%)_Gaz_RURALE  \
# 0                                            94
# 1                                          98.1
# 2                                             …
# 3                                             …
# 4                                             …
#
#   Combustible de cuisson utilisé (%)_Électricité_RURALE  \
# 0                                                0.3
# 1                                                0.3
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Combustible de cuisson utilisé (%)_Charbon_RURALE  \
# 0                                                 1
# 1                                               0.6
# 2                                                 …
# 3                                                 …
# 4                                                 …
#
#   Combustible de cuisson utilisé (%)_Bois énergie_RURALE  \
# 0                                                4.5
# 1                                                0.9
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
#   Combustible de cuisson utilisé (%)_Autre_RURALE  \
# 0                                             0.2
# 1                                             0.1
# 2                                               …
# 3                                               …
# 4                                               …
#
#   Distance moyenne des logements à la route goudronnée (Km)_RURALE
# 0                                                2.3
# 1                                                0.8
# 2                                                  …
# 3                                                  …
# 4                                                  …
#
# [5 rows x 668 columns]
